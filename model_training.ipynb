# %%
import pymongo
import pandas as pd
import joblib
from bson import ObjectId
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from constants import *
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
print(class_label)
# Out:
# ['Unhealthy', 'Healthy']

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["nutrition_label_data"]
collection = db["hk_fit_calorie_food_items"]

# %% [markdown]
# ## Read the data

# %%
# Read data from MongoDB
data = list(collection.find())

# Convert to DataFrame
df = pd.DataFrame(data)

# %%
df.mealType.value_counts()
# Out:
# mealType
# Breakfast                          1969
# Lunch                               883
# Snacks                              837
# Lunch, Dinner                       689
# Mid-Morning                         687
#                                    ...
# Post workout                          1
# test                                  1
# Lunch,Dinner, Others                  1
# Breakfast, Lunch, Dinner, Snack       1
# Breakfast/Lunch/Dinner                1
# Name: count, Length: 194, dtype: int64

# %% [markdown]
#   <p>sugar("Sugar", "g"),</p>
#   <p>sodium("Sodium", "mg"),</p>
#   <p>calcium("Calcium", "mg"),</p>
#   <p>potassium("Potassium", "mg"),</p>
#   <p>iron("Iron", "mg"),</p>
#   <p>magnesium("Magnesium", "mg"),</p>
#   <p>chloride("Chloride", "mg"),</p>
#   <p>zinc("Zinc", "mg"),</p>
#   <p>saturatedFat("Saturated Fat", "g"),</p>
#   <p>polyUnsaturatedFat("Polyunsaturated Fat", "g"),</p>
#   <p>transFat("Trans Fat", "g"),</p>
#   <p>monoUnsaturatedFat("Monounsaturated Fat", "g")</p>
#   <p>omega("Omega 3", "mg"),</p>
#   <p>Omega3("Omega 3", "mg"),</p>
#   <p>Cholesterol("Cholesterol", "mg"),</p>
#   <p>chromium("Chromium", "mcg"),</p>
#   <p>selenium("Selenium", "mcg"),</p>
#   <p>copper("Copper", "mg"),</p>
#   <p>iodine("Iodine", "mcg"),</p>
#   <p>manganese("Manganese", "mg"),</p>
#   <p>molybdenum("Molybdenum", "mcg"),</p>
#   <p>phosphorus("Phosphorus", "mg"),</p>
#   <p>vitaminC("Vitamin C", "mg"),</p>
#   <p>vitaminE("Vitamin E", "mg"),</p>
#   <p>vitaminD("Vitamin D", "mcg"),</p>
#   <p>vitaminK("Vitamin K", "mcg"),</p>
#   <p>vitaminD2("Vitamin D2", "mcg"),</p>
#   <p>vitaminD3("Vitamin D3", "mcg"),</p>
#   <p>vitaminB1("Vitamin B1", "mg"),</p>
#   <p>vitaminB2("Vitamin B2", "mg"),</p>
#   <p>vitaminB3("Vitamin B3", "mg"),</p>
#   <p>vitaminB5("Vitamin B5", "mg"),</p>
#   <p>vitaminB6("Vitamin B6", "mg"),</p>
#   <p>vitaminB7("Vitamin B7", "mcg")</p>
#   <p>vitaminB9("Vitamin B9", "mcg")</p>
#   <p>vitaminA("Vitamin A", "mcg"),</p>
#   <p>vitaminB12("Vitamin B12", "mcg");</p>

# %% [markdown]
# ## Data Preprocessing

# %%
df
# Out:
#                                      _id  Cholesterol addedSugar calories  \
# 0     ObjectId(5dea3e3528fdfeabbd8b1c66)         0.00          0      875
# 1     ObjectId(5dea3e3528fdfeabbd8b1c73)         0.00          0      602
# 2     ObjectId(5dea3e3528fdfeabbd8b1c91)         0.00          0    363.7
# 3     ObjectId(5dea3e3528fdfeabbd8b1c9c)         0.00          0     20.1
# 4     ObjectId(5dea3e3528fdfeabbd8b1ca6)         0.00          0      684
# ...                                  ...          ...        ...      ...
# 8903            6007eae528dbd50c69435ca1         0.00          0      0.0
# 8904            6007eae528dbd50c69435ca4        43.10          0   251.34
# 8905            6007eae528dbd50c69435ca7         0.00          0      0.0
# 8906            6007eae528dbd50c69435caa         0.75          0   122.17
# 8907            6007eae528dbd50c69435cad         0.00          0     56.0
#
#       carbs             createDt                   createdAt   fat fibre  \
# 0      22.3  2020-08-06 11:26:05  2020-08-06 05:56:05.899000  76.6  13.7
# 1      16.5  2020-08-06 11:26:06  2020-08-06 05:56:06.223000  51.2     0
# 2      27.9  2020-08-06 11:26:05  2020-08-06 05:56:05.904000    14  11.1
# 3       7.1  2020-08-06 11:26:06  2020-08-06 05:56:06.321000   0.1   1.9
# 4      13.9  2020-08-06 11:26:06  2020-08-06 05:56:06.216000  71.3   9.5
# ...     ...                  ...                         ...   ...   ...
# 8903    0.0  2021-01-20 14:03:41  2021-01-20 08:33:41.927000   0.0   0.0
# 8904   26.2  2021-01-20 14:03:41  2021-01-20 08:33:41.936000  8.05  5.29
# 8905    0.0  2021-01-20 14:03:41  2021-01-20 08:33:41.944000   0.0   0.0
# 8906  16.24  2021-01-20 14:03:41  2021-01-20 08:33:41.951000  3.09  8.61
# 8907   7.48  2021-01-20 14:03:41  2021-01-20 08:33:41.959000  2.27  1.32
#
#      foodChoice  ...  allergen cuisine foodFamily foodUsp  healthType  \
# 0           Veg  ...       NaN     NaN        NaN     NaN         NaN
# 1           Veg  ...       NaN     NaN        NaN     NaN         NaN
# 2           Veg  ...       NaN     NaN        NaN     NaN         NaN
# 3           Veg  ...       NaN     NaN        NaN     NaN         NaN
# 4           Veg  ...       NaN     NaN        NaN     NaN         NaN
# ...         ...  ...       ...     ...        ...     ...         ...
# 8903        Veg  ...       NaN     NaN        NaN     NaN         NaN
# 8904    Non Veg  ...       NaN     NaN        NaN     NaN         NaN
# 8905        Veg  ...       NaN     NaN        NaN     NaN         NaN
# 8906        Veg  ...       NaN     NaN        NaN     NaN         NaN
# 8907        Veg  ...       NaN     NaN        NaN     NaN         NaN
#
#       originalImage recipe subCategory foodType magnesium
# 0               NaN    NaN         NaN      NaN       NaN
# 1               NaN    NaN         NaN      NaN       NaN
# 2               NaN    NaN         NaN      NaN       NaN
# 3               NaN    NaN         NaN      NaN       NaN
# 4               NaN    NaN         NaN      NaN       NaN
# ...             ...    ...         ...      ...       ...
# 8903            NaN    NaN         NaN      NaN       NaN
# 8904            NaN    NaN         NaN      NaN       NaN
# 8905            NaN    NaN         NaN      NaN       NaN
# 8906            NaN    NaN         NaN      NaN       NaN
# 8907            NaN    NaN         NaN      NaN       NaN
#
# [8908 rows x 51 columns]

# %%
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8908 entries, 0 to 8907
# Data columns (total 51 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   _id                   8908 non-null   object
#  1   Cholesterol           5307 non-null   float64
#  2   addedSugar            4672 non-null   object
#  3   calories              8852 non-null   object
#  4   carbs                 8840 non-null   object
#  5   createDt              3104 non-null   object
#  6   createdAt             3104 non-null   object
#  7   fat                   8811 non-null   object
#  8   fibre                 8311 non-null   object
#  9   foodChoice            4920 non-null   object
#  10  foodId                8327 non-null   float64
#  11  foodName              8908 non-null   object
#  12  mealType              8908 non-null   object
#  13  minerals              6400 non-null   object
#  14  monoUnsaturatedFat    4580 non-null   float64
#  15  omega                 4505 non-null   float64
#  16  polyUnsaturatedFat    4569 non-null   object
#  17  protein               8842 non-null   object
#  18  servingSize           8904 non-null   object
#  19  servingUnit           8908 non-null   object
#  20  servingUnitType       4915 non-null   object
#  21  status                8908 non-null   object
#  22  transFat              4510 non-null   float64
#  23  updateDt              5022 non-null   object
#  24  updatedAt             5022 non-null   datetime64[ns]
#  25  vitamins              5669 non-null   object
#  26  weight                4655 non-null   object
#  27  applicable_for_diet   8908 non-null   object
#  28  include_in_diet_chat  8908 non-null   object
#  29  sugar                 4687 non-null   float64
#  30  alternateName         4082 non-null   object
#  31  volume                3028 non-null   object
#  32  size                  2884 non-null   object
#  33  maxQuantity           35 non-null     float64
#  34  minQuantity           35 non-null     float64
#  35  mealQuality           5915 non-null   object
#  36  createAt              6099 non-null   datetime64[ns]
#  37  image                 4981 non-null   object
#  38  updateAt              7791 non-null   datetime64[ns]
#  39  mealUSP               4329 non-null   object
#  40  servingUnitSize       4328 non-null   float64
#  41  allergen              2469 non-null   object
#  42  cuisine               2473 non-null   object
#  43  foodFamily            2686 non-null   object
#  44  foodUsp               2449 non-null   object
#  45  healthType            2479 non-null   object
#  46  originalImage         4152 non-null   object
#  47  recipe                1198 non-null   object
#  48  subCategory           1222 non-null   object
#  49  foodType              334 non-null    float64
#  50  magnesium             2 non-null      float64
# dtypes: datetime64[ns](3), float64(11), object(37)
# memory usage: 3.5+ MB
# Index(['_id', 'Cholesterol', 'addedSugar', 'calories', 'carbs', 'createDt',
#        'createdAt', 'fat', 'fibre', 'foodChoice', 'foodId', 'foodName',
#        'mealType', 'minerals', 'monoUnsaturatedFat', 'omega',
#        'polyUnsaturatedFat', 'protein', 'servingSize', 'servingUnit',
#        'servingUnitType', 'status', 'transFat', 'updateDt', 'updatedAt',
#        'vitamins', 'weight', 'applicable_for_diet', 'include_in_diet_chat',
#        'sugar', 'alternateName', 'volume', 'size', 'maxQuantity',
#        'minQuantity', 'mealQuality', 'createAt', 'image', 'updateAt',
#        'mealUSP', 'servingUnitSize', 'allergen', 'cuisine', 'foodFamily',
#        'foodUsp', 'healthType', 'originalImage', 'recipe', 'subCategory',
#        'foodType', 'magnesium'],
#       dtype='object')

# %%
# Extract vitamins data and normalize it into separate columns
df.drop(["magnesium"],inplace=True,axis=1)
vitamins_df = pd.json_normalize(df['vitamins'])
minerals_df = pd.json_normalize(df["minerals"])


# Merge the normalized vitamins data back into the original DataFrame
df = df.drop(columns=['vitamins']).join(vitamins_df)
df = df.drop(columns=['minerals']).join(minerals_df)

# %%
df.dropna(subset=["healthType"],inplace=True)
df['isHealthy'] = df['healthType'].replace({
    'Healthy':1,
    'Unhealthy':0
})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2479 entries, 320 to 8726
# Data columns (total 79 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   _id                   2479 non-null   object
#  1   Cholesterol           2401 non-null   float64
#  2   addedSugar            2427 non-null   object
#  3   calories              2479 non-null   object
#  4   carbs                 2478 non-null   object
#  5   createDt              908 non-null    object
#  6   createdAt             908 non-null    object
#  7   fat                   2459 non-null   object
#  8   fibre                 2301 non-null   object
#  9   foodChoice            2479 non-null   object
#  10  foodId                2479 non-null   float64
#  11  foodName              2479 non-null   object
#  12  mealType              2479 non-null   object
#  13  monoUnsaturatedFat    2459 non-null   float64
#  14  omega                 2446 non-null   float64
#  15  polyUnsaturatedFat    2460 non-null   object
#  16  protein               2476 non-null   object
#  17  servingSize           2479 non-null   object
#  18  servingUnit           2479 non-null   object
#  19  servingUnitType       2478 non-null   object
#  20  status                2479 non-null   object
#  21  transFat              2385 non-null   float64
#  22  updateDt              2479 non-null   object
#  23  updatedAt             2479 non-null   datetime64[ns]
#  24  weight                2445 non-null   object
#  25  applicable_for_diet   2479 non-null   object
#  26  include_in_diet_chat  2479 non-null   object
#  27  sugar                 2462 non-null   float64
#  28  alternateName         2325 non-null   object
#  29  volume                2180 non-null   object
#  30  size                  2158 non-null   object
#  31  maxQuantity           26 non-null     float64
#  32  minQuantity           26 non-null     float64
#  33  mealQuality           1662 non-null   object
#  34  createAt              1748 non-null   datetime64[ns]
#  35  image                 2479 non-null   object
#  36  updateAt              2479 non-null   datetime64[ns]
#  37  mealUSP               2476 non-null   object
#  38  servingUnitSize       2475 non-null   float64
#  39  allergen              2469 non-null   object
#  40  cuisine               2473 non-null   object
#  41  foodFamily            2477 non-null   object
#  42  foodUsp               2449 non-null   object
#  43  healthType            2479 non-null   object
#  44  originalImage         2455 non-null   object
#  45  recipe                1184 non-null   object
#  46  subCategory           1067 non-null   object
#  47  foodType              219 non-null    float64
#  48  vitaminC              1811 non-null   float64
#  49  vitaminE              1873 non-null   float64
#  50  vitaminD              2448 non-null   float64
#  51  vitaminK              1903 non-null   float64
#  52  vitaminD2             2452 non-null   float64
#  53  vitaminB1             1798 non-null   float64
#  54  vitaminD3             2454 non-null   float64
#  55  vitaminB2             1804 non-null   float64
#  56  vitaminB3             1794 non-null   float64
#  57  vitaminB5             1784 non-null   float64
#  58  vitaminB6             1800 non-null   float64
#  59  vitaminB7             1780 non-null   float64
#  60  vitaminB9             1792 non-null   float64
#  61  vitaminA              1809 non-null   float64
#  62  vitaminB12            1784 non-null   float64
#  63  chromium              2156 non-null   float64
#  64  potassium             2184 non-null   float64
#  65  calcium               2204 non-null   float64
#  66  magnesium             2169 non-null   object
#  67  manganese             2155 non-null   float64
#  68  saturatedFat          2340 non-null   float64
#  69  sodium                2281 non-null   float64
#  70  selenium              2163 non-null   float64
#  71  iron                  2186 non-null   float64
#  72  chloride              2145 non-null   float64
#  73  copper                2158 non-null   float64
#  74  iodine                2145 non-null   float64
#  75  zinc                  2167 non-null   float64
#  76  molybdenum            2149 non-null   float64
#  77  phosphorus            2167 non-null   float64
#  78  isHealthy             2479 non-null   int64
# dtypes: datetime64[ns](3), float64(39), int64(1), object(36)
# memory usage: 1.5+ MB
# C:\Users\adars\AppData\Local\Temp\ipykernel_19404\463486577.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['isHealthy'] = df['healthType'].replace({

# %%
# remove columns 
columns_to_remove= ["_id","createDt","createdAt","foodChoice",
                    "foodId","foodName","mealType","updateDt","updatedAt",
                    "maxQuantity","minQuantity","createAt","image","updateAt","magnesium",
                    "foodType","healthType","alternateName","status","applicable_for_diet","include_in_diet_chat",
                    "mealQuality","originalImage","recipe","subCategory","foodFamily","cuisine",
                    "allergen","servingUnitSize","mealUSP","size","omega","servingSize","servingUnit",
                    "servingUnitType","foodUsp","volume",
                    "molybdenum","copper","selenium","manganese","chromium","magnesium","chloride","iodine",
                    "vitaminD2","vitaminD3","zinc","phosphorus","calories","addedSugar",
                    "vitaminB1","vitaminB2","vitaminB3","vitaminB5","vitaminB7","vitaminB9"]

# Remove the specified columns
df.drop(columns=columns_to_remove, inplace=True)

# %%
# Convert object columns to float64
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = pd.to_numeric(df[column], errors='coerce')

# %%
# Fill all NaN values in the entire DataFrame with 0
df = df.fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2479 entries, 320 to 8726
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cholesterol         2479 non-null   float64
#  1   carbs               2479 non-null   float64
#  2   fat                 2479 non-null   float64
#  3   fibre               2479 non-null   float64
#  4   monoUnsaturatedFat  2479 non-null   float64
#  5   polyUnsaturatedFat  2479 non-null   float64
#  6   protein             2479 non-null   float64
#  7   transFat            2479 non-null   float64
#  8   weight              2479 non-null   float64
#  9   sugar               2479 non-null   float64
#  10  vitaminC            2479 non-null   float64
#  11  vitaminE            2479 non-null   float64
#  12  vitaminD            2479 non-null   float64
#  13  vitaminK            2479 non-null   float64
#  14  vitaminB6           2479 non-null   float64
#  15  vitaminA            2479 non-null   float64
#  16  vitaminB12          2479 non-null   float64
#  17  potassium           2479 non-null   float64
#  18  calcium             2479 non-null   float64
#  19  saturatedFat        2479 non-null   float64
#  20  sodium              2479 non-null   float64
#  21  iron                2479 non-null   float64
#  22  isHealthy           2479 non-null   int64
# dtypes: float64(22), int64(1)
# memory usage: 464.8 KB

# %%
df.isHealthy.value_counts()
# Out:
# isHealthy
# 1    1338
# 0    1141
# Name: count, dtype: int64

# %%
# Rename the columns 
# df.rename (columns={
#     "carbs":"Total Carbohydrate",
#     "fat":"Total Fat",
#     "saturatedFat":"Saturated Fat",
#     "polyUnsaturatedFat":"Poly Unsaturated Fat",
#     "monoUnsaturatedFat":"Mono Unsaturated Fat",
#     "transFat":"Trans Fat",
#     "sodium":"Sodium",
#     "sugar":"Total Sugars",
#     "protein":"Protein",
#     "fibre":"Dietary Fiber",
#     "potassium":"Potassium",
#     "vitaminA":"Vitamin A",
#     "vitaminB6":"Vitamin B6",
#     "vitaminB12":"Vitamin B12",
#     "vitaminC":"Vitamin C",
#     "vitaminD":"Vitamin D",
#     "vitaminE":"Vitamin E",
#     "vitaminK":"Vitamin K",
#     "calcium":"Calcium",
#     "iron":"Iron"
# },inplace=True)
df
# Out:
#       Cholesterol   carbs    fat  fibre  monoUnsaturatedFat  \
# 320           3.0   5.865  4.035   1.35               1.522
# 321           0.0   3.380  0.960   1.44               0.330
# 322           0.0  12.060  1.520   3.59               0.460
# 324           4.6   7.780  2.670   3.17               0.034
# 325           0.0   4.270  3.490   0.86               0.920
# ...           ...     ...    ...    ...                 ...
# 8721          0.0  17.740  0.590   0.00               0.170
# 8722          0.0  25.770  4.120   1.94               1.490
# 8723          0.0  23.020  4.250   2.94               1.430
# 8724          0.0   3.710  4.060   1.88               1.250
# 8726          0.0   3.830  0.280   1.68               0.010
#
#       polyUnsaturatedFat  protein  transFat  weight  sugar  ...  vitaminK  \
# 320                1.293     1.59      0.00   150.0   1.62  ...     39.45
# 321                0.400     1.03      0.01   150.0   0.45  ...     70.23
# 322                0.660     4.32      0.02   150.0   1.44  ...      9.40
# 324                0.207     1.98      0.00   150.0   1.49  ...     12.85
# 325                2.090     1.07      0.00    30.0   0.49  ...      4.72
# ...                  ...      ...       ...     ...    ...  ...       ...
# 8721               0.020     0.33      0.00    40.0   0.48  ...      0.01
# 8722               1.620     2.76      0.00    60.0   0.48  ...      0.88
# 8723               1.730     5.17      0.00   124.0   1.15  ...    145.52
# 8724               1.510     1.85      0.00   100.0   0.52  ...    172.65
# 8726               0.050     1.21      0.00    83.0   1.20  ...     29.20
#
#       vitaminB6  vitaminA  vitaminB12  potassium  calcium  saturatedFat  \
# 320       0.048     22.50       0.015     157.50    33.00         1.218
# 321       0.070     92.80       0.000     184.74    30.96         0.200
# 322       0.080     81.67       0.000     324.76    27.51         0.290
# 324       0.100     54.24       0.000     216.50    16.86         0.070
# 325       0.020     26.55       0.000      43.06     5.40         0.410
# ...         ...       ...         ...        ...      ...           ...
# 8721      0.000      0.13       0.010      10.19    10.95         0.420
# 8722      0.000      0.06       0.000      76.00    50.06         0.790
# 8723      0.180    194.35       0.000     359.95    58.24         0.850
# 8724      0.130    273.98       0.000     397.51    50.66         0.720
# 8726      0.040     75.25       0.000     190.33    24.18         0.040
#
#        sodium   iron  isHealthy
# 320    505.50  0.225          1
# 321   1645.17  0.840          1
# 322    205.48  1.330          1
# 324    345.10  0.320          1
# 325     41.55  0.410          1
# ...       ...    ...        ...
# 8721     2.71  0.010          1
# 8722   354.34  0.670          1
# 8723    96.29  1.190          1
# 8724    25.52  2.470          1
# 8726   217.15  0.380          1
#
# [2479 rows x 23 columns]

# %%
X = df.drop(['isHealthy'], axis = 1)
y = df['isHealthy']
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2479 entries, 320 to 8726
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cholesterol         2479 non-null   float64
#  1   carbs               2479 non-null   float64
#  2   fat                 2479 non-null   float64
#  3   fibre               2479 non-null   float64
#  4   monoUnsaturatedFat  2479 non-null   float64
#  5   polyUnsaturatedFat  2479 non-null   float64
#  6   protein             2479 non-null   float64
#  7   transFat            2479 non-null   float64
#  8   weight              2479 non-null   float64
#  9   sugar               2479 non-null   float64
#  10  vitaminC            2479 non-null   float64
#  11  vitaminE            2479 non-null   float64
#  12  vitaminD            2479 non-null   float64
#  13  vitaminK            2479 non-null   float64
#  14  vitaminB6           2479 non-null   float64
#  15  vitaminA            2479 non-null   float64
#  16  vitaminB12          2479 non-null   float64
#  17  potassium           2479 non-null   float64
#  18  calcium             2479 non-null   float64
#  19  saturatedFat        2479 non-null   float64
#  20  sodium              2479 non-null   float64
#  21  iron                2479 non-null   float64
# dtypes: float64(22)
# memory usage: 445.4 KB

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1983, 22)
# (496, 22)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)
accuracy_score(y_pred=y_pred, y_true=y_test)
# Out:
# 0.8991935483870968

# %%
joblib_file = "model.pkl"
joblib.dump(model, joblib_file)
# Out:
# ['model.pkl']

# %%
model
# Out:
# RandomForestClassifier()

# %%
prediction = model.predict(X_test.iloc[[0]])[0]
print(prediction)
print(class_label[prediction])
# Out:
# 1
# Healthy

# %%
print(class_label)
# Out:
# ['Unhealthy', 'Healthy']

# %%
X_test.iloc[0]
# Out:
# Cholesterol            12.700
# carbs                   3.170
# fat                     1.280
# fibre                   1.100
# monoUnsaturatedFat      0.030
# polyUnsaturatedFat      0.097
# protein                 0.420
# transFat                0.000
# weight                150.000
# sugar                   1.710
# vitaminC                2.920
# vitaminE                0.000
# vitaminD                4.110
# vitaminK                7.260
# vitaminB6               0.050
# vitaminA               25.850
# vitaminB12              0.000
# potassium              89.130
# calcium                 6.630
# saturatedFat            0.042
# sodium                315.790
# iron                    0.180
# Name: 1770, dtype: float64

# %%
y_test.iloc[0]
# Out:
# np.int64(1)

# %%
import pickle
# Step 1: Load the model from the pickle file
with open('model.pkl', 'rb') as file:
    model = pickle.load(file)
print(type(model))
# Out:
# <class 'numpy.ndarray'>
